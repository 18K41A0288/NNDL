# %% [markdown]
# <a href="https://colab.research.google.com/github/18K41A0288/NNDL/blob/main/Assignment%2004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split
import math
import random as r

l=0.02
m=r.randint(-50,50)
c=r.randint(-50,50)
print("m = ",m,"c = ",c)
m_iter=int(input("enter maximum number of iterations  "))
data = pd.read_excel("/content/drive/MyDrive/slr08.xls")


x = minmax_scale(list(data.iloc[:,0]))
y = minmax_scale(list(data.iloc[:,1]))

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)
print(len(x_train))
print(len(y_train))
print(len(x_test))
print(len(y_test))

ns=len(x_train)

def gm(y,x,m,c):
    return -1*(y-m*x-c)*x

def gc(y,x,m,c):
    return -1*(y-m*x-c)

for i in range(m_iter):
    for j in range(ns):        
        dm = -1*l*gm(y[j],x[j],m,c)
        dc = -1*l*gc(y[j],x[j],m,c)
        
        m = m + dm
        c = c + dc
        print("m = ",m,"c = ",c)

print("\n\noptimal value of m and c using SGD: ",m , c)
# Out:
# Streaming output truncated to the last 5000 lines.
# m =  -0.2399990238941342 c =  0.7420262034318461
# m =  -0.24053100894613216 c =  0.7408614785831535
# m =  -0.24062220462939118 c =  0.7406691022878116
# m =  -0.24115737879295493 c =  0.738002458610744
# m =  -0.24214273284973542 c =  0.736545848265938
# m =  -0.24074630776300593 c =  0.74280269865454
# m =  -0.2394974202353659 c =  0.7487684589105394
# m =  -0.23659762117579045 c =  0.7550933036518022
# m =  -0.22826801488705256 c =  0.7642813044817458
# m =  -0.22395962131196762 c =  0.7711415014139748
# m =  -0.23347162363252638 c =  0.7601014665921214
# m =  -0.23020400339210403 c =  0.7636921215331178
# m =  -0.23020400339210403 c =  0.7667079824183368
# m =  -0.2393233606497114 c =  0.7549423830993702
# m =  -0.23984925620097655 c =  0.7538682925388357
# m =  -0.24058747155888907 c =  0.7501899436002716
# m =  -0.2397357516850649 c =  0.7511084027179402
# m =  -0.23995234114748173 c =  0.7507718739295614
# ...
