# %% [markdown]
# <a href="https://colab.research.google.com/github/18K41A0288/NNDL/blob/main/Assignment%2009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import random as r
x=[0.2,0.4,0.6,0.8]
y=[3.4,3.8,4.2,4.6]
ns=len(x)
l=0.02
vm=vc=0
mc=0.9
m=r.randint(-50,50)
c=r.randint(-50,50)
print("m = ",m,"c = ",c)
m_iter=int(input("enter maximum number of iterations  "))
bs=int(input("enter batch size : "))
nb=int(ns/bs)

d=list()
for i in range(ns):
  d.append((x[i],y[i]))


def gm(d,m,c):
  s = 0
  for i in range(len(d)):
    s = s + (d[i][1]-m*d[i][0]-c)*d[i][0]
  return -1*(s/len(d))

def gc(d,m,c):
  s = 0
  for i in range(len(d)):
    s = s + (d[i][1]-m*d[i][0]-c)
  return -1*(s/len(d))

for i in range(m_iter):
  for j in range(nb):
    if j == nb:
      d1 = d[j*bs:]
    else:
      d1 = d[j*bs:(j+1)*bs]
    dm = -1*l*gm(d1,m,c)
    dc = -1*l*gc(d1,m,c)

    vm = vm*mc + dm
    vc = vc*mc + dc

    m = m + vm
    c = c + vc
    print("m = ",m,"\t c = ",c)

  r.shuffle(d)
print("\n\noptimal mean value occurs at m = ",m,"c = ",c)
# Out:
# m =  -14 c =  -6
# enter maximum number of iterations  1000
# enter batch size : 2
# m =  -13.914 	 c =  -5.724
# m =  -13.555323999999999 	 c =  -5.078324
# m =  -13.070844675199998 	 c =  -4.1800958800000005
# m =  -12.460530580288639 	 c =  -3.077380207648001
# m =  -11.845862552461949 	 c =  -1.8766253148965089
# m =  -11.085929947484757 	 c =  -0.5045713293877687
# m =  -10.298898053984487 	 c =  0.9312279836327004
# m =  -9.486249122903477 	 c =  2.3878117862183137
# m =  -8.631431958708589 	 c =  3.871788460541648
# m =  -7.846064377779022 	 c =  5.253720289974067
# m =  -7.087509683399869 	 c =  6.570537303197112
# m =  -6.397024718150608 	 c =  7.756961946501108
# m =  -5.766058100807861 	 c =  8.81357513372619
# m =  -5.215940394412449 	 c =  9.725916080562317
# m =  -4.743817928468027 	 c =  10.499095895836536
# m =  -4.3519252045708665 	 c =  11.098926355094346
# m =  -4.0490874699890345 	 c =  11.56572219418848
# m =  -3.8158296670905387 	 c =  11.850818530309365
# ...

# %% [markdown]
# ![9.jpeg](data:image/jpeg;base64,...)
