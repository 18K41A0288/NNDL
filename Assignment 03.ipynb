# %% [markdown]
# <a href="https://colab.research.google.com/github/18K41A0288/NNDL/blob/main/Assignment%2003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random as r
x=[0.2,0.4,0.6,0.8]
y=[3.4,3.8,4.2,4.6]
l=0.02
m=r.randint(-50,50)
c=r.randint(-50,50)
print("m = ",m,"c = ",c)
m_iter=int(input("enter maximum number of iterations  "))
gm = lambda x,y,m,c: -1*(y-m*x-c)*x
gc = lambda x,y,m,c: -1*(y-m*x-c)

for i in range(m_iter):
  for s in range(4):
    dm = -1*l*gm(y[s],x[s],m,c)
    dc = -1*l*gc(y[s],x[s],m,c)
    m=m+dm
    c=c+dc
    print("m = ",m,"\t c = ",c)
    s+=1

print("optimal mean value occurs at m = ",m,"c = ",c)
# Out:
# m =  10 c =  -33
# enter maximum number of iterations  1000
# m =  9.9456 	 c =  -33.016
# m =  9.61292672 	 c =  -33.1035456
# m =  9.052584003584 	 c =  -33.23696053248
# m =  8.352930822255411 	 c =  -33.38905905016013
# m =  8.705789231560848 	 c =  -33.28527716507029
# m =  8.751638366031417 	 c =  -33.27321160336751
# m =  8.509410125178404 	 c =  -33.3308849940468
# m =  8.04826917965521 	 c =  -33.43113302568228
# m =  8.47442639106532 	 c =  -33.305792669385184
# m =  8.58865229219893 	 c =  -33.27573322171845
# m =  8.404137354135496 	 c =  -33.31966534982879
# m =  7.986515638049603 	 c =  -33.41045267941268
# m =  8.425544004732597 	 c =  -33.281326689211795
# m =  8.552027724545919 	 c =  -33.248041499787234
# m =  8.378107829308247 	 c =  -33.289450998653344
# m =  7.968722087821105 	 c =  -33.37844789897664
# m =  8.409687998247277 	 c =  -33.24875204296894
# m =  8.538275259619102 	 c =  -33.21491328997635
# m =  8.366424464383496 	 c =  -33.25583014598483
# ...

# %% [markdown]
# hand calculations

# %% [markdown]
# ![WhatsApp Image 2021-05-30 at 4.32.55 PM.jpeg](data:image/jpeg;base64,...)
